# %%
import sys
assert sys.version_info >= (3, 5)
# Python ≥3.5 is required
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn import preprocessing
from sklearn import metrics
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import json
from pathlib import Path

# %%
data = pd.read_csv("02-19-2023.csv")

# %%
geoJSONDict = {

  "type": "FeatureCollection",
  "crs": {
    "type": "name",
    "properties": {
      "name": "urn:ogc:def:crs:OGC:1.3:CRS84"
    }
  },
  "features": []
}

# %%
# incident rate = (Cases/population)*100,000
# population = (Cases*100,000)/incident rate
data["Population"] = (data["Confirmed"] * 100000)/data["Incident_Rate"]
data["Case_Fatality_Ratio"] = (data["Case_Fatality_Ratio"]*100).round()
data.head(50)
# Out:
#     FIPS Admin2                Province_State          Country_Region  \
# 0    NaN    NaN                           NaN             Afghanistan
# 1    NaN    NaN                           NaN                 Albania
# 2    NaN    NaN                           NaN                 Algeria
# 3    NaN    NaN                           NaN                 Andorra
# 4    NaN    NaN                           NaN                  Angola
# 5    NaN    NaN                           NaN              Antarctica
# 6    NaN    NaN                           NaN     Antigua and Barbuda
# 7    NaN    NaN                           NaN               Argentina
# 8    NaN    NaN                           NaN                 Armenia
# 9    NaN    NaN  Australian Capital Territory               Australia
# 10   NaN    NaN               New South Wales               Australia
# 11   NaN    NaN            Northern Territory               Australia
# 12   NaN    NaN                    Queensland               Australia
# 13   NaN    NaN               South Australia               Australia
# 14   NaN    NaN                      Tasmania               Australia
# 15   NaN    NaN                      Victoria               Australia
# 16   NaN    NaN             Western Australia               Australia
# 17   NaN    NaN                           NaN                 Austria
# 18   NaN    NaN                           NaN              Azerbaijan
# 19   NaN    NaN                           NaN                 Bahamas
# 20   NaN    NaN                           NaN                 Bahrain
# 21   NaN    NaN                           NaN              Bangladesh
# 22   NaN    NaN                           NaN                Barbados
# 23   NaN    NaN                           NaN                 Belarus
# 24   NaN    NaN                       Antwerp                 Belgium
# 25   NaN    NaN                      Brussels                 Belgium
# 26   NaN    NaN                 East Flanders                 Belgium
# 27   NaN    NaN               Flemish Brabant                 Belgium
# 28   NaN    NaN                       Hainaut                 Belgium
# 29   NaN    NaN                         Liege                 Belgium
# 30   NaN    NaN                       Limburg                 Belgium
# 31   NaN    NaN                    Luxembourg                 Belgium
# 32   NaN    NaN                         Namur                 Belgium
# 33   NaN    NaN                       Unknown                 Belgium
# 34   NaN    NaN               Walloon Brabant                 Belgium
# 35   NaN    NaN                 West Flanders                 Belgium
# 36   NaN    NaN                           NaN                  Belize
# 37   NaN    NaN                           NaN                   Benin
# 38   NaN    NaN                           NaN                  Bhutan
# 39   NaN    NaN                           NaN                 Bolivia
# 40   NaN    NaN                           NaN  Bosnia and Herzegovina
# 41   NaN    NaN                           NaN                Botswana
# 42   NaN    NaN                          Acre                  Brazil
# 43   NaN    NaN                       Alagoas                  Brazil
# 44   NaN    NaN                         Amapa                  Brazil
# 45   NaN    NaN                      Amazonas                  Brazil
# 46   NaN    NaN                         Bahia                  Brazil
# 47   NaN    NaN                         Ceara                  Brazil
# 48     NaN                 Distrito Federal, Brazil   29717.325292
# 49     NaN                   Espirito Santo, Brazil   32884.824506
#
#     Case_Fatality_Ratio   Population
# 0                 378.0   38928341.0
# 1                 108.0    2877800.0
# 2                 254.0   43851043.0
# 3                  34.0      77265.0
# 4                 184.0   32866268.0
# 5                   0.0          NaN
# 6                 160.0      97928.0
# 7                 130.0   45195777.0
# 8                 195.0    2963234.0
# 9                  10.0     428100.0
# 10                 16.0    8118000.0
# 11                  9.0     245600.0
# 12                 15.0    5115500.0
# 13                 15.0    1756500.0
# 14                  9.0     535500.0
# 15                 25.0    6629900.0
# 16                  7.0    2630600.0
# 17                 37.0    9006400.0
# 18                122.0   10139175.0
# 19                222.0     393248.0
# 20                 22.0    1701583.0
# 21                144.0  164689383.0
# 22                 54.0     287371.0
# 23                 72.0    9449321.0
# 24                  0.0    1857986.0
# 25                  0.0    1208542.0
# 26                  0.0    1515064.0
# 27                  0.0    1146175.0
# 28                  0.0    1344241.0
# 29                  0.0    1106992.0
# 30                  0.0     874048.0
# 31                  0.0     284638.0
# 32                  0.0     494325.0
# 33               5336.0          NaN
# 34                  0.0     403599.0
# 35                  0.0    1195796.0
# 36                 97.0     397621.0
# 37                 58.0   12123198.0
# 38                  3.0     771612.0
# 39                188.0   11673029.0
# 40                405.0    3280815.0
# 41                 85.0    2351625.0
# 42                127.0     881935.0
# 43                215.0    3337357.0
# 44                117.0     845731.0
# 45                230.0    4144597.0
# 46                176.0   14873064.0
# 47                194.0    9132078.0
# 48                132.0    3015268.0
# 49                114.0    4018650.0

# %%
clean_data = data.drop(['FIPS', 'Admin2','Province_State','Country_Region','Last_Update','Deaths','Recovered','Active','Combined_Key','Incident_Rate','Confirmed','Population'], axis=1)
clean_data = clean_data.dropna()
clean_data.loc[~(clean_data==0.0).all(axis=1)]
# Out:
#             Lat       Long_  Case_Fatality_Ratio
# 0     33.939110   67.709953                378.0
# 1     41.153300   20.168300                108.0
# 2     28.033900    1.659600                254.0
# 3     42.506300    1.521800                 34.0
# 4    -11.202700   17.873900                184.0
# ...         ...         ...                  ...
# 4011  31.952200   35.233200                 81.0
# 4012  39.904200  116.407400                  0.0
# 4013  15.552727   48.516388               1807.0
# 4014 -13.133897   27.849332                118.0
# 4015 -19.015438   29.154857                215.0
#
# [3922 rows x 3 columns]

# %%
clean_data["Case_Fatality_Ratio"].sum()
# Out:
# 609432.0

# %%
#The mistake made here is Im rendering EACH AND EVERY covid case 
#Instead of that, create an object with long, lat and total case count.
#Hence we should only have approx 4000 json objects instead of 600 million+
#TODO: Figure out how mapbox is gonna render it



for i in range(len(clean_data)):
    
    longitude = clean_data.iloc[i]['Long_']
    latitude = clean_data.iloc[i]['Lat']
    data_points = int(clean_data.iloc[i]['Case_Fatality_Ratio'])
    
    
    for x in range(data_points):
        geometry = {
        "geometry": {
          "coordinates": [
            longitude,
            latitude
          ]
        }
      }
        geoJSONDict["features"].append(geometry)
    

json_object = json.dumps(geoJSONDict, separators=(',', ":"))
with open("../server/case_fatality_ratio.json", "w") as outfile:
    outfile.write(json_object)

# %%
csv_total
