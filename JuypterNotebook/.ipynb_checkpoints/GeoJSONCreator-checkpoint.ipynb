# %%
import sys
assert sys.version_info >= (3, 5)
# Python ≥3.5 is required
import sklearn
assert sklearn.__version__ >= "0.20"
import numpy as np
import os
import tarfile
import urllib
import pandas as pd
import urllib.request
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve
from sklearn import preprocessing
from sklearn import metrics
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import json
from pathlib import Path

# %%
data = pd.read_csv("02-19-2023.csv")

# %%
geoJSONDict = {

  "type": "FeatureCollection",
  "crs": {
    "type": "name",
    "properties": {
      "name": "urn:ogc:def:crs:OGC:1.3:CRS84"
    }
  },
  "features": []
}

# %%
# incident rate = (Cases/population)*100,000
# population = (Cases*100,000)/incident rate
data["Population"] = (data["Confirmed"] * 100000)/data["Incident_Rate"]
data["Case_Fatality_Ratio"] = (data["Case_Fatality_Ratio"]*100).round()
data = data.sort_values(by='Case_Fatality_Ratio', ascending=False)
data.head(50)
# Out:
#          FIPS      Admin2   Province_State Country_Region  \
# 1386  90017.0  Unassigned         Illinois             US
# 2936  90040.0  Unassigned         Oklahoma             US
# 367       NaN         NaN              NaN   Korea, North
# 1075  90012.0  Unassigned          Florida             US
# 33        NaN         NaN          Unknown        Belgium
# 2108  90027.0  Unassigned        Minnesota             US
# 381       NaN         NaN              NaN     MS Zaandam
# 3119  72999.0  Unassigned      Puerto Rico             US
# 4013      NaN         NaN              NaN          Yemen
# 994   90008.0  Unassigned         Colorado             US
# 422       NaN         NaN        Michoacan         Mexico
# 641       NaN         NaN              NaN          Sudan
# 427       NaN         NaN           Puebla         Mexico
# 437       NaN         NaN         Veracruz         Mexico
# 500       NaN         NaN       Lambayeque           Peru
# 506       NaN         NaN            Piura           Peru
# 511       NaN         NaN          Ucayali           Peru
# 408       NaN         NaN  Baja California         Mexico
# 2483  32029.0      Storey           Nevada             US
# 497       NaN         NaN              Ica           Peru
# 502       NaN         NaN           Loreto           Peru
# 419       NaN         NaN          Hidalgo         Mexico
# 420       NaN         NaN          Jalisco         Mexico
# 512       NaN         NaN          Unknown           Peru
# 421       NaN         NaN           Mexico         Mexico
# 493       NaN         NaN           Callao           Peru
# 125       NaN         NaN            Hubei          China
# 507       NaN         NaN             Puno           Peru
# 3546  48403.0      Sabine            Texas             US
# 499       NaN         NaN      La Libertad           Peru
# 412       NaN         NaN        Chihuahua         Mexico
# 418       NaN         NaN         Guerrero         Mexico
# 423       NaN         NaN          Morelos         Mexico
# 666       NaN         NaN              NaN          Syria
# 431       NaN         NaN          Sinaloa         Mexico
# 142       NaN         NaN          Unknown          China
# 2412  31075.0       Grant         Nebraska             US
# 2379  31009.0      Blaine         Nebraska             US
# 435       NaN         NaN         Tlaxcala         Mexico
# 410       NaN         NaN         Campeche         Mexico
# 510       NaN         NaN           Tumbes           Peru
# 432       NaN         NaN           Sonora         Mexico
# 617       NaN         NaN              NaN        Somalia
# 438       NaN         NaN          Yucatan         Mexico
# 496       NaN         NaN          Huanuco           Peru
# 498       NaN         NaN            Junin           Peru
# 414       NaN         NaN         Coahuila         Mexico
# 3506  48311.0    McMullen            Texas             US
# 197       NaN         NaN              NaN          Egypt
# 439       NaN         NaN        Zacatecas         Mexico
#
#               Last_Update        Lat       Long_  Confirmed  Deaths  \
# 1386  2023-02-20 04:21:05        NaN         NaN         65    5038
# 422                 789.0    4825401.0
# 641                 786.0   43849269.0
# 427                 764.0    6604451.0
# 437                 731.0    8539862.0
# 500                 730.0    1310800.0
# 506                 729.0    2048000.0
# 511                 720.0     589100.0
# 408                 719.0    3634868.0
# 2483                714.0       4123.0
# 497                 700.0     975200.0
# 502                 691.0    1027600.0
# 419                 684.0    3086414.0
# 420                 683.0    8409693.0
# 512                 662.0          NaN
# 421                 654.0   17427790.0
# 493                 639.0    1129900.0
# 125                 626.0   59170000.0
# 507                 619.0    1238000.0
# 3546                615.0      10542.0
# 499                 606.0    2016800.0
# 412                 594.0    3801487.0
# 418                 579.0    3657048.0
# 423                 553.0    2044058.0
# 666                 551.0   17500657.0
# 431                 549.0    3156674.0
# 142                 540.0          NaN
# 2412                531.0        623.0
# 2379                526.0        465.0
# 435                 526.0    1380011.0
# 410                 520.0    1000617.0
# 510                 517.0     251500.0
# 432                 515.0    3074745.0
# 617                 498.0   15893219.0
# 438                 491.0    2259098.0
# 496                 490.0     760300.0
# 498                 490.0    1361500.0
# 414                 485.0    3218720.0
# 3506                484.0        743.0
# 197                 481.0  102334403.0
# 439                 480.0    1666426.0

# %%
data = data.drop([1386,2936,367])
data
# Out:
#          FIPS      Admin2   Province_State  Country_Region  \
# 1075  90012.0  Unassigned          Florida              US
# 33        NaN         NaN          Unknown         Belgium
# 2108  90027.0  Unassigned        Minnesota              US
# 381       NaN         NaN              NaN      MS Zaandam
# 3119  72999.0  Unassigned      Puerto Rico              US
# ...       ...         ...              ...             ...
# 3852  90054.0  Unassigned    West Virginia              US
# 3922  90055.0  Unassigned        Wisconsin              US
# 3954  90056.0  Unassigned          Wyoming              US
# 3991      NaN         NaN  Channel Islands  United Kingdom
# 4004      NaN         NaN          Unknown  United Kingdom
#
#               Last_Update      Lat   Long_  Confirmed  Deaths  Recovered  \
# 1075  2023-02-20 04:21:05      NaN     NaN       3289    2124        NaN
# 33    2023-02-20 04:21:05      NaN     NaN      63090   33663        NaN
# 2108  2023-02-20 04:21:05      NaN     NaN        902     417        NaN
# 381   2023-02-20 04:21:05      NaN     NaN          9       2        NaN
# 3119  2023-02-20 04:21:05      NaN     NaN      26318    5771        NaN
# ...                   ...      ...     ...        ...     ...        ...
# 3852  2021-07-31 23:21:38      NaN     NaN          0       0        NaN
# 3922  2023-02-20 04:21:05      NaN     NaN          0       0        NaN
# 3954  2023-01-08 23:21:00      NaN     NaN          0       0        NaN
# 3991  2023-02-20 04:21:05  49.3723 -2.3644          0       0        NaN
# 4004  2023-02-20 04:21:05      NaN     NaN          0     336        NaN
#
#       Active                     Combined_Key  Incident_Rate  \
# 1075     NaN          Unassigned, Florida, US            NaN
# 33       NaN                 Unknown, Belgium            NaN
# 2108     NaN        Unassigned, Minnesota, US            NaN
# 381      NaN                       MS Zaandam            NaN
# 3119     NaN      Unassigned, Puerto Rico, US            NaN
# ...      ...                              ...            ...
# 3852     NaN    Unassigned, West Virginia, US            NaN
# 3922     NaN        Unassigned, Wisconsin, US            NaN
# 3954     NaN          Unassigned, Wyoming, US            NaN
# 3991     NaN  Channel Islands, United Kingdom            0.0
# 4004     NaN          Unknown, United Kingdom            NaN
#
#       Case_Fatality_Ratio  Population
# 1075               6458.0         NaN
# 33                 5336.0         NaN
# 2108               4623.0         NaN
# 381                2222.0         NaN
# 3119               2193.0         NaN
# ...                   ...         ...
# 3852                  NaN         NaN
# 3922                  NaN         NaN
# 3954                  NaN         NaN
# 3991                  NaN         NaN
# 4004                  NaN         NaN
#
# [4013 rows x 15 columns]

# %%
us_data = data.loc[data['Country_Region']=='US']
data = data[data['Country_Region']!='US']
data
# Out:
#       FIPS Admin2   Province_State  Country_Region          Last_Update  \
# 33     NaN    NaN          Unknown         Belgium  2023-02-20 04:21:05
# 381    NaN    NaN              NaN      MS Zaandam  2023-02-20 04:21:05
# 4013   NaN    NaN              NaN           Yemen  2023-02-20 04:21:05
# 422    NaN    NaN        Michoacan          Mexico  2023-02-20 04:21:05
# 641    NaN    NaN              NaN           Sudan  2023-02-20 04:21:05
# ...    ...    ...              ...             ...                  ...
# 436    NaN    NaN          Unknown          Mexico  2023-02-20 04:21:05
# 463    NaN    NaN          Unknown     Netherlands  2023-02-20 04:21:05
# 639    NaN    NaN          Unknown           Spain  2023-02-20 04:21:05
# 3991   NaN    NaN  Channel Islands  United Kingdom  2023-02-20 04:21:05
# 4004   NaN    NaN          Unknown  United Kingdom  2023-02-20 04:21:05
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 33          NaN         NaN      63090   33663        NaN     NaN
# 381         NaN         NaN          9       2        NaN     NaN
# 4013  15.552727   48.516388      11945    2159        NaN     NaN
# 422   19.566500 -101.706800     114366    9026        NaN     NaN
# 641   12.862800   30.217600      63775    5011        NaN     NaN
# ...         ...         ...        ...     ...        ...     ...
# 436         NaN         NaN          0       0        NaN     NaN
# 463         NaN         NaN          0       2        NaN     NaN
# 639         NaN         NaN          0       0        NaN     NaN
# 3991  49.372300   -2.364400          0       0        NaN     NaN
# 4004        NaN         NaN          0     336        NaN     NaN
#
#                          Combined_Key  Incident_Rate  Case_Fatality_Ratio  \
# 33                   Unknown, Belgium            NaN               5336.0
# 381                        MS Zaandam            NaN               2222.0
# 4013                            Yemen      40.048994               1807.0
# 422                 Michoacan, Mexico    2370.082818                789.0
# 641                             Sudan     145.441421                786.0
# ...                               ...            ...                  ...
# 436                   Unknown, Mexico            NaN                  NaN
# 463              Unknown, Netherlands            NaN                  NaN
# 639                    Unknown, Spain            NaN                  NaN
# 3991  Channel Islands, United Kingdom       0.000000                  NaN
# 4004          Unknown, United Kingdom            NaN                  NaN
#
#       Population
# 33           NaN
# 381          NaN
# 4013  29825968.0
# 422    4825401.0
# 641   43849269.0
# ...          ...
# 436          NaN
# 463          NaN
# 639          NaN
# 3991         NaN
# 4004         NaN
#
# [736 rows x 15 columns]

# %%
us_data
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 1075  90012.0  Unassigned        Florida             US  2023-02-20 04:21:05
# 2108  90027.0  Unassigned      Minnesota             US  2023-02-20 04:21:05
# 3119  72999.0  Unassigned    Puerto Rico             US  2023-02-20 04:21:05
# 994   90008.0  Unassigned       Colorado             US  2023-02-20 04:21:05
# 2483  32029.0      Storey         Nevada             US  2023-02-20 04:21:05
# ...       ...         ...            ...            ...                  ...
# 3243  90046.0  Unassigned   South Dakota             US  2023-02-20 04:21:05
# 3753  90051.0  Unassigned       Virginia             US  2020-12-21 13:27:30
# 3852  90054.0  Unassigned  West Virginia             US  2021-07-31 23:21:38
# 3922  90055.0  Unassigned      Wisconsin             US  2023-02-20 04:21:05
# 3954  90056.0  Unassigned        Wyoming             US  2023-01-08 23:21:00
#
#             Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 1075        NaN         NaN       3289    2124        NaN     NaN
# 2108        NaN         NaN        902     417        NaN     NaN
# 3119        NaN         NaN      26318    5771        NaN     NaN
# 994         NaN         NaN        256      23        NaN     NaN
# 2483  39.448755 -119.525021        196      14        NaN     NaN
# ...         ...         ...        ...     ...        ...     ...
# 3243        NaN         NaN          0       0        NaN     NaN
# 3753        NaN         NaN          0       0        NaN     NaN
# 3852        NaN         NaN          0       0        NaN     NaN
# 3922        NaN         NaN          0       0        NaN     NaN
# 3954        NaN         NaN          0       0        NaN     NaN
#
#                        Combined_Key  Incident_Rate  Case_Fatality_Ratio  \
# 1075        Unassigned, Florida, US            NaN               6458.0
# 2108      Unassigned, Minnesota, US            NaN               4623.0
# 3119    Unassigned, Puerto Rico, US            NaN               2193.0
# 994        Unassigned, Colorado, US            NaN                898.0
# 2483             Storey, Nevada, US    4753.820034                714.0
# ...                             ...            ...                  ...
# 3243   Unassigned, South Dakota, US            NaN                  NaN
# 3753       Unassigned, Virginia, US            NaN                  NaN
# 3852  Unassigned, West Virginia, US            NaN                  NaN
# 3922      Unassigned, Wisconsin, US            NaN                  NaN
# 3954        Unassigned, Wyoming, US            NaN                  NaN
#
#       Population
# 1075         NaN
# 2108         NaN
# 3119         NaN
# 994          NaN
# 2483      4123.0
# ...          ...
# 3243         NaN
# 3753         NaN
# 3852         NaN
# 3922         NaN
# 3954         NaN
#
# [3277 rows x 15 columns]

# %%
#data struct to store states
# for every state in us_data: 
# get average of Case_Fatality_Ratio, median of lat and long, country
# insert row into data

states =  us_data.Province_State.values.tolist()
states = list(dict.fromkeys(states))

for state in states:
    tempDf = us_data.loc[us_data['Province_State']==state]
    stateDf = tempDf.groupby('Province_State', as_index=False).Case_Fatality_Ratio.max()
    lat = tempDf.groupby('Province_State', as_index=False).Lat.median().iloc[0]['Lat']
    long = tempDf.groupby('Province_State', as_index=False).Long_.median().iloc[0]['Long_']
    country = "US"
    stateDf["Lat"] = lat
    stateDf["Long_"] = long
    stateDf["Country_Region"] = country
    stateDf
    data = data.append(stateDf, ignore_index=True)
# Out:
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)
# C:\Users\Shawn\AppData\Local\Temp\ipykernel_20736\1243832962.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data = data.append(stateDf, ignore_index=True)

# %%
sampleDf = data.loc[data['Province_State']=='Florida']
data
# Out:
#      FIPS Admin2            Province_State Country_Region  \
# 0     NaN    NaN                   Unknown        Belgium
# 1     NaN    NaN                       NaN     MS Zaandam
# 2     NaN    NaN                       NaN          Yemen
# 3     NaN    NaN                 Michoacan         Mexico
# 4     NaN    NaN                       NaN          Sudan
# ..    ...    ...                       ...            ...
# 790   NaN    NaN            Virgin Islands             US
# 791   NaN    NaN            American Samoa             US
# 792   NaN    NaN  Northern Mariana Islands             US
# 793   NaN    NaN          Diamond Princess             US
# 794   NaN    NaN                 Recovered             US
#
#              Last_Update        Lat       Long_  Confirmed   Deaths  \
# 0    2023-02-20 04:21:05        NaN         NaN    63090.0  33663.0
# 1    2023-02-20 04:21:05        NaN         NaN        9.0      2.0
# 2    2023-02-20 04:21:05  15.552727   48.516388    11945.0   2159.0
# 3    2023-02-20 04:21:05  19.566500 -101.706800   114366.0   9026.0
# 4    2023-02-20 04:21:05  12.862800   30.217600    63775.0   5011.0
# ..                   ...        ...         ...        ...      ...
# 790                  NaN  18.335800  -64.896300        NaN      NaN
# 791                  NaN -14.271000 -170.132000        NaN      NaN
# 792                  NaN  15.097900  145.673900        NaN      NaN
# 793                  NaN        NaN         NaN        NaN      NaN
# 794                  NaN        NaN         NaN        NaN      NaN
#
#      Recovered  Active       Combined_Key  Incident_Rate  Case_Fatality_Ratio  \
# 0          NaN     NaN   Unknown, Belgium            NaN               5336.0
# 1          NaN     NaN         MS Zaandam            NaN               2222.0
# 2          NaN     NaN              Yemen      40.048994               1807.0
# 3          NaN     NaN  Michoacan, Mexico    2370.082818                789.0
# 4          NaN     NaN              Sudan     145.441421                786.0
# ..         ...     ...                ...            ...                  ...
# 790        NaN     NaN                NaN            NaN                 53.0
# 791        NaN     NaN                NaN            NaN                 41.0
# 792        NaN     NaN                NaN            NaN                 30.0
# 793        NaN     NaN                NaN            NaN                  0.0
# 794        NaN     NaN                NaN            NaN                  NaN
#
#      Population
# 0           NaN
# 1           NaN
# 2    29825968.0
# 3     4825401.0
# 4    43849269.0
# ..          ...
# 790         NaN
# 791         NaN
# 792         NaN
# 793         NaN
# 794         NaN
#
# [795 rows x 15 columns]

# %%
clean_data = data.drop(['FIPS', 'Admin2','Province_State','Country_Region','Last_Update','Deaths','Recovered','Active','Combined_Key','Incident_Rate','Confirmed','Population'], axis=1)
clean_data = clean_data.dropna()
clean_data.loc[~(clean_data==0.0).all(axis=1)]
# Out:
#            Lat       Long_  Confirmed   Deaths  Case_Fatality_Ratio
# 2    15.552727   48.516388    11945.0   2159.0               1807.0
# 3    19.566500 -101.706800   114366.0   9026.0                789.0
# 4    12.862800   30.217600    63775.0   5011.0                786.0
# 5    19.041400  -98.206300   218997.0  16731.0                764.0
# 6    19.173800  -96.134200   234451.0  17141.0                731.0
# ..         ...         ...        ...      ...                  ...
# 721  50.973900    5.342000   348771.0      0.0                  0.0
# 722  -7.109500  177.649300     2805.0      0.0                  0.0
# 723  35.745200   95.995600      782.0      0.0                  0.0
# 724  37.269200  106.165500     1276.0      0.0                  0.0
# 725  31.692700   88.092400     1647.0      0.0                  0.0
#
# [715 rows x 5 columns]

# %%
clean_data = clean_data.sort_values(by='Case_Fatality_Ratio', ascending=False)
clean_data.head(50)
# Out:
# Empty DataFrame
# Columns: [Lat, Long_, Confirmed, Deaths, Recovered, Case_Fatality_Ratio]
# Index: []

# %%
#The mistake made here is Im rendering EACH AND EVERY covid case 
#Instead of that, create an object with long, lat and total case count.
#Hence we should only have approx 4000 json objects instead of 600 million+
#TODO: Figure out how mapbox is gonna render it



for i in range(len(clean_data)):
    
    longitude = clean_data.iloc[i]['Long_']
    latitude = clean_data.iloc[i]['Lat']
    data_points = int(clean_data.iloc[i]['Case_Fatality_Ratio'])
    
    
    for x in range(data_points):
        geometry = {
        "geometry": {
          "coordinates": [
            longitude,
            latitude
          ]
        }
      }
        geoJSONDict["features"].append(geometry)
    

json_object = json.dumps(geoJSONDict, separators=(',', ":"))
with open("../server/case_fatality_ratio.json", "w") as outfile:
    outfile.write(json_object)

# %%
csv_total
